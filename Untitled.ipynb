# %%
import pandas as pd
permits = pd.read_csv('data_files/permits.csv')
# Out:
# /var/folders/1b/w1kczxkd6c35q23928bnt7ch0000gn/T/ipykernel_22950/4263592117.py:2: DtypeWarning: Columns (1,3) have mixed types. Specify dtype option on import or set low_memory=False.
#   permits = pd.read_csv('data_files/permits.csv')

# %%
zillow = pd.read_csv('data_files/ZillowData.csv')
zillow.head()
# Out:
#    RegionID  SizeRank         RegionName    RegionType StateName State  \
# 0    274772         0   Northeast Dallas  Neighborhood        TX    TX
# 1    112345         1           Maryvale  Neighborhood        AZ    AZ
# 2    192689         2           Paradise  Neighborhood        NV    NV
# 3    270958         3    Upper West Side  Neighborhood        NY    NY
# 4    118208         4  South Los Angeles  Neighborhood        CA    CA
#
#           City                           Metro          CountyName  \
# 0       Dallas     Dallas-Fort Worth-Arlington       Dallas County
# 1      Phoenix         Phoenix-Mesa-Scottsdale     Maricopa County
# 2    Las Vegas    Las Vegas-Henderson-Paradise        Clark County
# 3     New York     New York-Newark-Jersey City     New York County
# 4  Los Angeles  Los Angeles-Long Beach-Anaheim  Los Angeles County
#
#    2000-01-31  ...  2021-09-30  2021-10-31  2021-11-30  2021-12-31  \
# ...

# %%
zillow_philly = zillow[zillow['City'] == 'Philadelphia']
zillow_philly
# Out:
#        RegionID  SizeRank        RegionName    RegionType StateName State  \
# 180      214232       183     Oxford Circle  Neighborhood        PA    PA
# 226      214146       230             Olney  Neighborhood        PA    PA
# 274      274834       282     West Oak Lane  Neighborhood        PA    PA
# 293      274451       303           Mayfair  Neighborhood        PA    PA
# 316      403167       326         Overbrook  Neighborhood        PA    PA
# ...         ...       ...               ...           ...       ...   ...
# 10300    209607     11154   Crestmont Farms  Neighborhood        PA    PA
# 10415    753825     11286  Woodland Terrace  Neighborhood        PA    PA
# 11523    273240     12575         Chinatown  Neighborhood        PA    PA
# 11604    753827     12669     West Parkside  Neighborhood        PA    PA
# 11621    208863     12688           Byberry  Neighborhood        PA    PA
#
#                City                           Metro           CountyName  \
# ...

# %%
zillow_philly.nunique()
# Out:
# RegionID      142
# SizeRank      142
# RegionName    142
# RegionType      1
# StateName       1
#              ...
# 2022-02-28    141
# 2022-03-31    141
# 2022-04-30    142
# 2022-05-31    142
# 2022-06-30    142
# Length: 279, dtype: int64

# %%
zillow_philly [0:9].isnull().sum()
# Out:
# RegionID      0
# SizeRank      0
# RegionName    0
# RegionType    0
# StateName     0
#              ..
# 2022-02-28    0
# 2022-03-31    0
# 2022-04-30    0
# 2022-05-31    0
# 2022-06-30    0
# Length: 279, dtype: int64
